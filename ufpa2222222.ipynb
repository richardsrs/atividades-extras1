# %% [markdown]
# <a href="https://colab.research.google.com/github/richardsrs/atividades-extras1/blob/main/ufpa2222222.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def math

input()
