# %% [markdown]
# <a href="https://colab.research.google.com/github/richardsrs/atividades-extras1/blob/main/atividadeextra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def gerador_quantizacao():

    n_niveis = int(input("Digite o número de níveis de quantização: "))
    n_bits = math.ceil(math.log2(n_niveis))

    print(f"\n--- Resultado ---")
    print(f"Niveis desejados: {n_niveis}")
    print(f"Bits necessários: {n_bits}")
    print(f"Capacidade real com esses bits: {2**n_bits} combinações")
    print(f"---------------------\n")


    print(f"Combinações de {n_bits} bits: ")

    for i in range(2**n_bits):
        combinacao = f"{i:0{n_bits}b}"
        print (f"Nivel {i:3}: {combinacao}")

if __name__ == "__main__":
    gerador_quantizacao()
# Out:
# Digite o número de níveis de quantização: 15
#
# --- Resultado ---
# Niveis desejados: 15
# Bits necessários: 4
# Capacidade real com esses bits: 16 combinações
# ---------------------
#
# Combinações de 4 bits:
# Nivel   0: 0000
# Nivel   1: 0001
# Nivel   2: 0010
# Nivel   3: 0011
# Nivel   4: 0100
# Nivel   5: 0101
# Nivel   6: 0110
# Nivel   7: 0111
# Nivel   8: 1000
# Nivel   9: 1001
# Nivel  10: 1010
# Nivel  11: 1011
# Nivel  12: 1100
# Nivel  13: 1101
# Nivel  14: 1110
# Nivel  15: 1111
